# %%
from transformers import pipeline
import re
from rapidfuzz import fuzz

# %%
import re
from rapidfuzz import fuzz

def normalize_text(text: str) -> str:
    text = text.lower()

    replacements = {
        '3': 'e', '4': 'a', '5': 's',
        '0': 'o', '@': 'a', '$': 's'
    }
    for k, v in replacements.items():
        text = text.replace(k, v)

    text = text.replace('1', 'l')

    text = re.sub(r'[^a-z0-9\s]', '', text)

    text = re.sub(
        r'(\b[a-z]\s+){2,}[a-z]\b',
        lambda m: m.group(0).replace(" ", ""),
        text
    )

    text = re.sub(r'\s+', ' ', text).strip()

    return text


def fuzzy_check(text):
    # targets = ["kill", "suicide", "rape", "nude"]
    targets = []

    for word in targets:
        score = max(
            fuzz.partial_ratio(text, word),
            fuzz.ratio(text, word)
        )

        if score > 80:
            return True, word

    return False, None

# %%
model_2 = pipeline(
    "text-classification",
    model="cardiffnlp/twitter-roberta-base-offensive",
    return_all_scores=True
)

def extract_scores(output):
    """
    Handles both:
    - single label output
    - multi-label output
    """

    # Case 1: list of dicts (correct multi-label)
    if isinstance(output, list) and isinstance(output[0], dict):
        return {r["label"].lower(): r["score"] for r in output}

    # Case 2: nested list
    if isinstance(output, list) and isinstance(output[0], list):
        return {r["label"].lower(): r["score"] for r in output[0]}

    # Case 3: single dict
    if isinstance(output, dict):
        return {output["label"].lower(): output["score"]}

    return {}


def predict_model_2(text):
    output = model_2(text, top_k=None)

    # Normalize structure
    if isinstance(output[0], list):
        output = output[0]

    scores = {o["label"]: o["score"] for o in output}

    return scores.get("offensive", 0.0)
# Out:
# Loading weights: 100%|██████████| 201/201 [00:00<00:00, 17260.16it/s]
# RobertaForSequenceClassification LOAD REPORT from: cardiffnlp/twitter-roberta-base-offensive
# Key                             | Status     |  |
# --------------------------------+------------+--+-
# roberta.embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.

# %%
def decide(score):
    if score > 0.9:
        return "BLOCKED"
    elif score > 0.6:
        return "FLAGGED"
    else:
        return "APPROVED"

# %%
def moderate_with_model(text, predict_fn):
    processed = normalize_text(text)

    # Fuzzy check first
    fuzzy_hit, word = fuzzy_check(processed)
    if fuzzy_hit:
        return {
            "text": text,
            "processed": processed,
            "status": "BLOCKED",
            "reason": "fuzzy_match",
            "word": word
        }

    # Model prediction
    score = predict_fn(processed)

    return {
        "text": text,
        "processed": processed,
        "toxicity": score,
        "status": decide(score)
    }

# %%
tests = [
    "Hello, how are you?",
    "I hate you",
    "You are stupid",
    "Send me nudes",
    "I will kill you",
    "k i l l",
    "k!ll",
    "ki11",
    "Let's build something amazing",
    "You are annoying",
    "Go to hell",
    "kill time",
    "Fuck you"
]
print("Model 2 output :-")
for t in tests:
    print("TEXT:", t)
    print("Model 2:", moderate_with_model(t, predict_model_2))

    print("-" * 80)
# Out:
# Model 2 output :-
# TEXT: Hello, how are you?
# Model 2: {'text': 'Hello, how are you?', 'processed': 'hello how are you', 'toxicity': 0.0630854144692421, 'status': 'APPROVED'}
# --------------------------------------------------------------------------------
# TEXT: I hate you
# Model 2: {'text': 'I hate you', 'processed': 'i hate you', 'toxicity': 0.6579686999320984, 'status': 'FLAGGED'}
# --------------------------------------------------------------------------------
# TEXT: You are stupid
# Model 2: {'text': 'You are stupid', 'processed': 'you are stupid', 'toxicity': 0.9125449657440186, 'status': 'BLOCKED'}
# --------------------------------------------------------------------------------
# TEXT: Send me nudes
# Model 2: {'text': 'Send me nudes', 'processed': 'send me nudes', 'toxicity': 0.49784427881240845, 'status': 'APPROVED'}
# --------------------------------------------------------------------------------
# TEXT: I will kill you
# Model 2: {'text': 'I will kill you', 'processed': 'i will kill you', 'toxicity': 0.6740319728851318, 'status': 'FLAGGED'}
# --------------------------------------------------------------------------------
# TEXT: k i l l
# Model 2: {'text': 'k i l l', 'processed': 'kill', 'toxicity': 0.3277215361595154, 'status': 'APPROVED'}
# --------------------------------------------------------------------------------
# TEXT: k!ll
# Model 2: {'text': 'k!ll', 'processed': 'kll', 'toxicity': 0.27480387687683105, 'status': 'APPROVED'}
# --------------------------------------------------------------------------------
# TEXT: ki11
# Model 2: {'text': 'ki11', 'processed': 'kill', 'toxicity': 0.3277215361595154, 'status': 'APPROVED'}
# --------------------------------------------------------------------------------
# TEXT: Let's build something amazing
# Model 2: {'text': "Let's build something amazing", 'processed': 'lets build something amazing', 'toxicity': 0.11070335656404495, 'status': 'APPROVED'}
# --------------------------------------------------------------------------------
# TEXT: You are annoying
# Model 2: {'text': 'You are annoying', 'processed': 'you are annoying', 'toxicity': 0.7952974438667297, 'status': 'FLAGGED'}
# --------------------------------------------------------------------------------
# TEXT: Go to hell
# Model 2: {'text': 'Go to hell', 'processed': 'go to hell', 'toxicity': 0.8494699001312256, 'status': 'FLAGGED'}
# --------------------------------------------------------------------------------
# TEXT: kill time
# Model 2: {'text': 'kill time', 'processed': 'kill time', 'toxicity': 0.27053433656692505, 'status': 'APPROVED'}
# --------------------------------------------------------------------------------
# TEXT: Fuck you
# Model 2: {'text': 'Fuck you', 'processed': 'fuck you', 'toxicity': 0.8740860223770142, 'status': 'FLAGGED'}
# --------------------------------------------------------------------------------

# %%
print("MODEL 2 OUTPUT:")
out = model_2("lets meet and kill some time", top_k=None)
print(out)
# Out:
# MODEL 2 OUTPUT:
# [{'label': 'non-offensive', 'score': 0.751270592212677}, {'label': 'offensive', 'score': 0.248729407787323}]
